# %%
import pandas as pd

# %%
# import csv file 
d1 = pd.read_csv("Data/credit_change.csv")
d1.head()
# Out:
#    Unnamed: 0      ID Customer_ID  Month  Annual_Income  \
# 0           0  0x1602   CUS_0xd40      1       19114.12
# 1           1  0x1608   CUS_0xd40      7       19114.12
# 2           2  0x1626  CUS_0xb891      1       30689.89
# 3           3  0x1627  CUS_0xb891      2       30689.89
# 4           4  0x1628  CUS_0xb891      3       30689.89
#
#    Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# 0            1824.843333                  3                4              3
# 1            1824.843333                  3                4              3
# 2            2612.490833                  2                5              4
# 3            2612.490833                  2                5              4
# 4            2612.490833                  2                5              4
#
#    Num_of_Loan  ... Num_Credit_Inquiries  Outstanding_Debt  \
# 0          4.0  ...                  4.0            809.98
# ...

# %%
d1.dtypes
# Out:
# Unnamed: 0                    int64
# ID                           object
# Customer_ID                  object
# Month                         int64
# Annual_Income               float64
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                 float64
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment      float64
# Num_Credit_Inquiries        float64
# Outstanding_Debt            float64
# Credit_Utilization_Ratio    float64
# Credit_History_Age          float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly     float64
# Payment_Behaviour            object
# Monthly_Balance             float64
# Credit_Score                 object
# dtype: object

# %%
# import csv file 
d2 = pd.read_csv("Data/credit_score_new.csv")
d2.head()
# Out:
#    Unnamed: 0      ID Customer_ID           Name   Age    Occupation  Month  \
# 0           0  0x1602   CUS_0xd40  Aaron Maashoh  23.0     Scientist      1
# 1           1  0x1608   CUS_0xd40  Aaron Maashoh  23.0     Scientist      7
# 2           2  0x1626  CUS_0xb891         Jasond  55.0  Entrepreneur      1
# 3           3  0x1627  CUS_0xb891         Jasond  55.0  Entrepreneur      2
# 4           4  0x1628  CUS_0xb891         Jasond  55.0  Entrepreneur      3
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0       19114.12            1824.843333                  3  ...
# 1       19114.12            1824.843333                  3  ...
# 2       30689.89            2612.490833                  2  ...
# 3       30689.89            2612.490833                  2  ...
# 4       30689.89            2612.490833                  2  ...
#
#    Num_Credit_Inquiries  Outstanding_Debt  Credit_Utilization_Ratio  \
# ...

# %%
d2.dtypes
# Out:
# Unnamed: 0                    int64
# ID                           object
# Customer_ID                  object
# Name                         object
# Age                         float64
# Occupation                   object
# Month                         int64
# Annual_Income               float64
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                 float64
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment      float64
# Num_Credit_Inquiries        float64
# Outstanding_Debt            float64
# Credit_Utilization_Ratio    float64
# Credit_History_Age          float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly     float64
# Payment_Behaviour            object
# Monthly_Balance             float64
# Credit_Score                 object
# ...

# %%
# import csv file 
d3 = pd.read_csv("Data/customer_info.csv")
d3.head()
# Out:
#    Unnamed: 0 Customer_ID           Name   Age    Occupation
# 0           0   CUS_0xd40  Aaron Maashoh  23.0     Scientist
# 1           2  CUS_0xb891         Jasond  55.0  Entrepreneur
# 2           9  CUS_0x1cdb         Deepaa  21.0     Developer
# 3          14  CUS_0x95ee             Np  31.0        Lawyer
# 4          18  CUS_0x284a         Nadiaq  33.0        Lawyer

# %%
d3.dtypes
# Out:
# Unnamed: 0       int64
# Customer_ID     object
# Name            object
# Age            float64
# Occupation      object
# dtype: object
