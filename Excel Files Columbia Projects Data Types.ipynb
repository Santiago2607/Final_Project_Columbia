# %%
import pandas as pd

# %%
# import csv file 
d1 = pd.read_csv("Data/credit_change.csv", index_col=[0])
d1.head()
# Out:
#        ID Customer_ID  Month  Annual_Income  Monthly_Inhand_Salary  \
# 0  0x1602   CUS_0xd40      1       19114.12            1824.843333
# 1  0x1608   CUS_0xd40      7       19114.12            1824.843333
# 2  0x1626  CUS_0xb891      1       30689.89            2612.490833
# 3  0x1627  CUS_0xb891      2       30689.89            2612.490833
# 4  0x1628  CUS_0xb891      3       30689.89            2612.490833
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                  3                4              3          4.0
# 1                  3                4              3          4.0
# 2                  2                5              4          1.0
# 3                  2                5              4          1.0
# 4                  2                5              4          1.0
#
#                                         Type_of_Loan  ...  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...  ...
# ...

# %%
d1.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                         int64
# Annual_Income               float64
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                 float64
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment      float64
# Num_Credit_Inquiries        float64
# Outstanding_Debt            float64
# Credit_Utilization_Ratio    float64
# Credit_History_Age          float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly     float64
# Payment_Behaviour            object
# Monthly_Balance             float64
# Credit_Score                 object
# dtype: object

# %%
# import csv file 
d2 = pd.read_csv("Data/credit_score_new.csv", index_col=[0])
d2.head()
# Out:
#        ID Customer_ID           Name   Age    Occupation  Month  \
# 0  0x1602   CUS_0xd40  Aaron Maashoh  23.0     Scientist      1
# 1  0x1608   CUS_0xd40  Aaron Maashoh  23.0     Scientist      7
# 2  0x1626  CUS_0xb891         Jasond  55.0  Entrepreneur      1
# 3  0x1627  CUS_0xb891         Jasond  55.0  Entrepreneur      2
# 4  0x1628  CUS_0xb891         Jasond  55.0  Entrepreneur      3
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                  3                4
# 1       19114.12            1824.843333                  3                4
# 2       30689.89            2612.490833                  2                5
# 3       30689.89            2612.490833                  2                5
# 4       30689.89            2612.490833                  2                5
#
#    ...  Num_Credit_Inquiries  Outstanding_Debt Credit_Utilization_Ratio  \
# ...

# %%
d2.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Name                         object
# Age                         float64
# Occupation                   object
# Month                         int64
# Annual_Income               float64
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                 float64
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment      float64
# Num_Credit_Inquiries        float64
# Outstanding_Debt            float64
# Credit_Utilization_Ratio    float64
# Credit_History_Age          float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly     float64
# Payment_Behaviour            object
# Monthly_Balance             float64
# Credit_Score                 object
# dtype: object

# %%
# import csv file 
d3 = pd.read_csv("Data/customer_info.csv", index_col=[0])
d3.head()
# Out:
#    Customer_ID           Name   Age    Occupation
# 0    CUS_0xd40  Aaron Maashoh  23.0     Scientist
# 2   CUS_0xb891         Jasond  55.0  Entrepreneur
# 9   CUS_0x1cdb         Deepaa  21.0     Developer
# 14  CUS_0x95ee             Np  31.0        Lawyer
# 18  CUS_0x284a         Nadiaq  33.0        Lawyer

# %%
d3.dtypes
# Out:
# Customer_ID     object
# Name            object
# Age            float64
# Occupation      object
# dtype: object

# %%
d1.to_csv("first_table.csv")

# %%
d3.to_csv("third_table.csv")
